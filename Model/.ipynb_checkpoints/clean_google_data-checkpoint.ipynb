# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.Category.unique() # 1.9 is not a category
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df[df['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df[df['App'] == 'Life Made WI-Fi Touchscreen Photo Frame'] # check other records with the same name
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df = df.drop(df[df['Category'] == '1.9'].index)

# %%
df[df['Category'] == '1.9']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.Rating.unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
df.Reviews.unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df.Size.unique() # has K and M
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
# check for missing values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df[df['Type'].isnull()] # it has a 0 price so free
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df.loc[9148, 'Type'] = 'Free'

# %%
df[df['Type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.loc[9148]
# Out:
# App               Command & Conquer: Rivals
# Category                             FAMILY
# Rating                                  NaN
# Reviews                                   0
# Size                     Varies with device
# Installs                                  0
# Type                                   Free
# Price                                     0
# Content Rating                 Everyone 10+
# Genres                             Strategy
# Last Updated                  June 28, 2018
# Current Ver              Varies with device
# Android Ver              Varies with device
# Name: 9148, dtype: object

# %%
df[df['Android Ver'].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
df = df.drop(df[df['Android Ver'].isnull()].index)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          0
# dtype: int64

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
duplicates = df[df['App'].duplicated()]
duplicates
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews                Size        Installs  Type Price  \
# ...

# %%
df[df['App'] == 'Quick PDF Scanner + OCR FREE'] # differ only by reviews
# Out:
#                               App  Category  Rating Reviews  \
# 222  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 285  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80804
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 222  Varies with device  5,000,000+  Free     0       Everyone  Business
# 285  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 222  February 26, 2018  Varies with device  4.0.3 and up
# 285  February 26, 2018  Varies with device  4.0.3 and up

# %%
df[df['App'] == 'OfficeSuite : Free Office + PDF Editor'] # differ only by reviews
# Out:
#                                         App  Category  Rating  Reviews Size  \
# 194  OfficeSuite : Free Office + PDF Editor  BUSINESS     4.3  1002861  35M
# 293  OfficeSuite : Free Office + PDF Editor  BUSINESS     4.3  1002859  35M
#
#          Installs  Type Price Content Rating    Genres    Last Updated  \
# 194  100,000,000+  Free     0       Everyone  Business  August 2, 2018
# 293  100,000,000+  Free     0       Everyone  Business  August 2, 2018
#
#     Current Ver Android Ver
# 194   9.7.14188  4.1 and up
# 293   9.7.14188  4.1 and up

# %%
df[df['App'] == 'Slack'] # differ only by reviews
# Out:
#        App  Category  Rating Reviews                Size    Installs  Type  \
# 240  Slack  BUSINESS     4.4   51507  Varies with device  5,000,000+  Free
# 294  Slack  BUSINESS     4.4   51510  Varies with device  5,000,000+  Free
#
#     Price Content Rating    Genres    Last Updated         Current Ver  \
# 240     0       Everyone  Business  August 2, 2018  Varies with device
# 294     0       Everyone  Business  August 2, 2018  Varies with device
#
#             Android Ver
# 240  Varies with device
# 294  Varies with device

# %%
df = df.loc[df.groupby('App')['Reviews'].idxmax()]
df # grouped by app and removed records wth lower reviews
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
duplicates = df[df['App'].duplicated()]
duplicates # no more duplicates
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# size 
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# np.int64(8116)

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# np.int64(314)

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# np.int64(1227)

# %%
# 1227+314+8116 = 9657
len(df)
# Out:
# 9657

# %%
def convert_size(size):
    if isinstance(size, str):
        if 'k' in size:
            return float(size.replace('k', "")) * 1024
        elif 'M' in size:
            return float(size.replace('M', "")) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

# %%
df['Size'] = df['Size'].apply(convert_size)

# %%
df.rename(columns={'Size': "Size_in_Bytes"}, inplace=True)

# %%
df
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
df['Size_in_Bytes'] = df['Size_in_Bytes'].apply(lambda x: (x/(1024*1024)))
df.rename(columns={'Size_in_Bytes': "Size_in_MB"}, inplace=True)

# %%
df['Size_in_MB'] = df['Size_in_MB'].round(2)

# %%
df
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9657 entries, 8884 to 882
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9657 non-null   object
#  1   Category        9657 non-null   object
#  2   Rating          8194 non-null   float64
#  3   Reviews         9657 non-null   object
#  4   Size_in_MB      8430 non-null   float64
#  5   Installs        9657 non-null   object
#  6   Type            9657 non-null   object
#  7   Price           9657 non-null   object
#  8   Content Rating  9657 non-null   object
#  9   Genres          9657 non-null   object
#  10  Last Updated    9657 non-null   object
#  11  Current Ver     9649 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
df['Installs'].unique()
# Out:
# array(['500+', '1,000,000+', '10,000+', '100+', '100,000+', '500,000+',
#        '10,000,000+', '5,000+', '50,000+', '5+', '1,000+', '10+',
#        '50,000,000+', '100,000,000+', '5,000,000+', '50+', '0+', '1+',
#        '500,000,000+', '0', '1,000,000,000+'], dtype=object)

# %%
# remove characters from installs and have it int
df['Installs'] = df['Installs'].apply(lambda x: x.replace('+', "") if '+' in str(x) else x)
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',', "") if ',' in str(x) else x)
df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %%
df
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
# binning categories
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['Installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
# remove $ sign
df['Price'] = df['Price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df
# Out:
#                                                    App       Category  Rating  \
# 8884              "i DT" Fútbol. Todos Somos Técnicos.         SPORTS     NaN
# 8532                     +Download 4 Instagram Twitter         SOCIAL     4.5
# 324                         - Free Comics - Comic Apps         COMICS     3.5
# 4541                                                .R          TOOLS     4.5
# 4636                                            /u/app  COMMUNICATION     4.7
# ...                                                ...            ...     ...
# 6334                           뽕티비 - 개인방송, 인터넷방송, BJ방송  VIDEO_PLAYERS     NaN
# 4362                                        💎 I'm rich      LIFESTYLE     3.8
# 2575     💘 WhatsLov: Smileys of love, stickers and GIF         SOCIAL     4.6
# 7559  📏 Smart Ruler ↔️ cm/inch measuring for homework!          TOOLS     4.0
# 882   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍  ENTERTAINMENT     4.7
#
# ...

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# Rating               15.149632
# Size_in_MB           12.705809
# Current Ver           0.082841
# Category              0.000000
# Reviews               0.000000
# App                   0.000000
# Installs              0.000000
# Type                  0.000000
# Content Rating        0.000000
# Price                 0.000000
# Genres                0.000000
# Last Updated          0.000000
# Android Ver           0.000000
# Installs_category     0.000000
# dtype: float64

# %%
plt.figure(figsize=(16, 6)) # figure size
numeric_cols = ['Rating', 'Reviews', 'Size_in_MB', 'Installs', 'Price'] # numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True) # reviews and installs are highly correlated
# Out:
# <Axes: >

# %%
#df.dropna(subset=['Current Ver',], inplace=True)
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Low                   875
# Very low              453
# Moderate               87
# More than moderate     30
# no                     15
# High                    3
# Very High               0
# Top Notch               0
# Name: count, dtype: int64

# %%
mean_by_cat = df.groupby('Category')['Rating'].transform('mean')
df['Rating'] = df['Rating'].fillna(mean_by_cat)

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# Size_in_MB           12.705809
# Current Ver           0.082841
# Category              0.000000
# Rating                0.000000
# Reviews               0.000000
# App                   0.000000
# Installs              0.000000
# Type                  0.000000
# Content Rating        0.000000
# Price                 0.000000
# Genres                0.000000
# Last Updated          0.000000
# Android Ver           0.000000
# Installs_category     0.000000
# dtype: float64

# %%
df.dropna(subset = ['Size_in_MB', 'Current Ver'], inplace=True)

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# App                  0.0
# Category             0.0
# Rating               0.0
# Reviews              0.0
# Size_in_MB           0.0
# Installs             0.0
# Type                 0.0
# Price                0.0
# Content Rating       0.0
# Genres               0.0
# Last Updated         0.0
# Current Ver          0.0
# Android Ver          0.0
# Installs_category    0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8422 entries, 8884 to 882
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App                8422 non-null   object
#  1   Category           8422 non-null   object
#  2   Rating             8422 non-null   float64
#  3   Reviews            8422 non-null   object
#  4   Size_in_MB         8422 non-null   float64
#  5   Installs           8422 non-null   int64
#  6   Type               8422 non-null   object
#  7   Price              8422 non-null   float64
#  8   Content Rating     8422 non-null   object
#  9   Genres             8422 non-null   object
#  10  Last Updated       8422 non-null   object
#  11  Current Ver        8422 non-null   object
#  12  Android Ver        8422 non-null   object
#  13  Installs_category  8422 non-null   category
# dtypes: category(1), float64(3), int64(1), object(9)
# memory usage: 929.7+ KB

# %%
df['Reviews'] = df['Reviews'].astype('int')
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8422 entries, 8884 to 882
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App                8422 non-null   object
#  1   Category           8422 non-null   object
#  2   Rating             8422 non-null   float64
#  3   Reviews            8422 non-null   int64
#  4   Size_in_MB         8422 non-null   float64
#  5   Installs           8422 non-null   int64
#  6   Type               8422 non-null   object
#  7   Price              8422 non-null   float64
#  8   Content Rating     8422 non-null   object
#  9   Genres             8422 non-null   object
#  10  Last Updated       8422 non-null   datetime64[ns]
#  11  Current Ver        8422 non-null   object
#  12  Android Ver        8422 non-null   object
#  13  Installs_category  8422 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(3), int64(2), object(7)
# ...

# %%
df.to_csv('clean_googleplaystore.csv', index = False)

# %%
def clean_data(file_path):
    # load csv into df
    df = pd.read_csv(file_path)

    # clean specific values for this table
    df = specific_clean(df)

    # drop name duplicates and keep the record with highest nb of reviews
    df = df.loc[df.groupby('App')['Reviews'].idxmax()]
    
    # clean size
    df['Size'] = df['Size'].apply(convert_size)
    df['Size'] = df['Size'].apply(lambda x: (x/(1024*1024)))
    df.rename(columns={'Size': "Size_in_MB"}, inplace=True)
    df['Size_in_MB'] = df['Size_in_MB'].round(2)

    # clean installs
    df = clean_installs(df)
    
    # binning categories
    df = bin_categories(df)
    
    # clean price
    df = clean_price(df)
    
    # fill null ratings
    mean_by_cat = df.groupby('Category')['Rating'].transform('mean')
    df['Rating'] = df['Rating'].fillna(mean_by_cat)
    df['Rating'] = df['Rating'].round(2)
    
    # drop some values
    df.dropna(subset = ['Size_in_MB', 'Current Ver'], inplace=True)
    
    # concert datatypes
    df['Reviews'] = df['Reviews'].astype('int')
    df['Last Updated'] = pd.to_datetime(df['Last Updated'])

    return df

def clean_reviews(file_path):
    reviews = pd.read_csv(file_path)
    df = reviews.dropna()
    mean_sentiment = df.groupby('App')['Sentiment_Polarity'].mean()
    new_df = df.copy()
    new_df['Mean_App_Sentiment'] = new_df['App'].map(mean_sentiment)
    cols = ['Translated_Review','Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity' ]
    df = df.drop(cols)
    return new_df


df1 = clean_data('googleplaystore.csv')
df2 = clean_reviews('googleplaystore_user_reviews.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 49
#      45     new_df['Mean_App_Sentiment'] = new_df['App'].map(mean_sentiment)
#      46     return new_df
# ---> 49 df1 = clean_data('googleplaystore.csv')
#      50 df2 = clean_reviews('googleplaystore_user_reviews.csv')
#
# Cell In[4], line 6, in clean_data(file_path)
#       3 df = pd.read_csv(file_path)
#       5 # clean specific values for this table
# ----> 6 df = specific_clean(df)
#       8 # drop name duplicates and keep the record with highest nb of reviews
#       9 df = df.loc[df.groupby('App')['Reviews'].idxmax()]
#
# NameError: name 'specific_clean' is not defined

# %%
df1 = pd.read_csv('googleplaystore.csv')
df2 = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
cols = ['Translated_Review','Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity' ]
df2 = df2.drop(cols)
df2
    #df_merged = pd.merge(df1, df2, on='App', how='left')
    #df_merged['Mean_App_Sentiment'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 cols = ['Translated_Review','Sentiment', 'Sentiment_Polarity', 'Sentiment_Subjectivity' ]
# ----> 2 df2 = df2.drop(cols)
#       3 df2
#       4     #df_merged = pd.merge(df1, df2, on='App', how='left')
#       5     #df_merged['Mean_App_Sentiment'].fillna(0, inplace=True)
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
# ...
